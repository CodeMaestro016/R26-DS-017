# %%
# -*- coding: utf-8 -*-
"""
model_gru.py  — same style as lstm_training.ipynb
INPUT  : (batch, 30, 36)
OUTPUT : 6 class probabilities
"""

from google.colab import drive
drive.mount('/content/drive')
import subprocess
subprocess.run(['pip', 'install', 'seaborn', '-q'])
print('Ready.')

import os, json
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, callbacks
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import (
    classification_report, confusion_matrix,
    f1_score, accuracy_score
)

print(f'TensorFlow : {tf.__version__}')
print(f'GPU        : {len(tf.config.list_physical_devices("GPU")) > 0}')

PIE_PATH     = '/content/drive/MyDrive/PIE'
FEATURE_PATH = f'{PIE_PATH}/features'
MODEL_PATH   = f'{PIE_PATH}/models'
os.makedirs(MODEL_PATH, exist_ok=True)

SEQ_LEN    = 30
N_FEATURES = 36
N_CLASSES  = 6
BATCH_SIZE = 32
EPOCHS     = 100
PATIENCE   = 15
SEED       = 42

tf.random.set_seed(SEED)
np.random.seed(SEED)

LABEL_NAMES = ['Waiting','Hesitant','Committed',
               'Distracted','Aggressive','Jaywalk']

# ── Load Data ─────────────────────────────────────────────────
X_train = np.load(f'{FEATURE_PATH}/X_train.npy')
y_train = np.load(f'{FEATURE_PATH}/y_train.npy')
X_val   = np.load(f'{FEATURE_PATH}/X_val.npy')
y_val   = np.load(f'{FEATURE_PATH}/y_val.npy')
X_test  = np.load(f'{FEATURE_PATH}/X_test.npy')
y_test  = np.load(f'{FEATURE_PATH}/y_test.npy')

print('Data loaded:')
print(f'  X_train : {X_train.shape}  y_train : {y_train.shape}')
print(f'  X_val   : {X_val.shape}   y_val   : {y_val.shape}')
print(f'  X_test  : {X_test.shape}  y_test  : {y_test.shape}')

assert not np.isnan(X_train).any()
assert not np.isnan(X_val).any()
assert not np.isnan(X_test).any()
print('No NaN values. Data is clean.')

print('\nClass distribution (train):')
for i, name in enumerate(LABEL_NAMES):
    n   = int(np.sum(y_train == i))
    pct = n / len(y_train) * 100
    bar = '█' * int(pct/2)
    print(f'  {i} {name:<15} {n:>5,}  ({pct:5.1f}%)  {bar}')

raw_weights   = compute_class_weight(
    'balanced', classes=np.arange(N_CLASSES), y=y_train)
class_weights = {i: float(w) for i, w in enumerate(raw_weights)}

print('\nClass weights:')
for i, name in enumerate(LABEL_NAMES):
    print(f'  {i} {name:<15}  weight={class_weights[i]:.3f}')

# ── Build GRU ─────────────────────────────────────────────────
def build_gru_model(seq_len=30, n_features=36, n_classes=6):
    inputs = keras.Input(shape=(seq_len, n_features),
                         name='sequence_input')
    x = layers.GRU(
        128, return_sequences=True,
        kernel_regularizer=keras.regularizers.l2(1e-4),
        name='gru_1')(inputs)
    x = layers.Dropout(0.3, name='dropout_1')(x)
    x = layers.GRU(
        64, return_sequences=False,
        kernel_regularizer=keras.regularizers.l2(1e-4),
        name='gru_2')(x)
    x = layers.Dropout(0.3, name='dropout_2')(x)
    outputs = layers.Dense(n_classes, activation='softmax',
                           name='mental_state_output')(x)
    return keras.Model(inputs=inputs, outputs=outputs,
                       name='GRU_MentalState')

model = build_gru_model(SEQ_LEN, N_FEATURES, N_CLASSES)
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-3),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
model.summary()
print(f'\nTotal parameters : {model.count_params():,}')

# ── Callbacks ─────────────────────────────────────────────────
MODEL_SAVE_PATH = f'{MODEL_PATH}/gru_mental_state_best.h5'
cb_list = [
    callbacks.ModelCheckpoint(MODEL_SAVE_PATH, monitor='val_loss',
                              save_best_only=True, verbose=1),
    callbacks.EarlyStopping(monitor='val_loss', patience=PATIENCE,
                            restore_best_weights=True, verbose=1),
    callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5,
                                patience=7, min_lr=1e-6, verbose=1),
    callbacks.CSVLogger(f'{MODEL_PATH}/gru_training_log.csv'),
]

print('\nStarting GRU training...')
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=EPOCHS, batch_size=BATCH_SIZE,
    class_weight=class_weights,
    callbacks=cb_list, verbose=1
)

print(f'\nFinished at epoch {len(history.history["loss"])}')
print(f'Best val_loss    : {min(history.history["val_loss"]):.4f}')
print(f'Best val_accuracy: {max(history.history["val_accuracy"]):.4f}')

# ── Training Curves ───────────────────────────────────────────
fig, axes = plt.subplots(1, 2, figsize=(14, 5))
epochs_ran = range(1, len(history.history['loss'])+1)

axes[0].plot(epochs_ran, history.history['loss'],
             label='Train loss', color='#2563EB', linewidth=2)
axes[0].plot(epochs_ran, history.history['val_loss'],
             label='Val loss', color='#DC2626', linewidth=2, linestyle='--')
best_ep = np.argmin(history.history['val_loss'])+1
axes[0].axvline(x=best_ep, color='gray', linestyle=':',
                alpha=0.7, label=f'Best epoch {best_ep}')
axes[0].set_title('Loss', fontsize=14, fontweight='bold')
axes[0].set_xlabel('Epoch'); axes[0].legend(); axes[0].grid(True, alpha=0.3)

axes[1].plot(epochs_ran, history.history['accuracy'],
             label='Train acc', color='#2563EB', linewidth=2)
axes[1].plot(epochs_ran, history.history['val_accuracy'],
             label='Val acc', color='#DC2626', linewidth=2, linestyle='--')
axes[1].axhline(y=0.85, color='green', linestyle='--',
                alpha=0.7, label='Target 85%')
axes[1].set_title('Accuracy', fontsize=14, fontweight='bold')
axes[1].set_xlabel('Epoch'); axes[1].set_ylim([0,1])
axes[1].legend(); axes[1].grid(True, alpha=0.3)

plt.suptitle('GRU Mental State Classifier — Training History',
             fontsize=15, fontweight='bold')
plt.tight_layout()
plt.savefig(f'{MODEL_PATH}/gru_training_curves.png', dpi=150)
plt.show()
print(f'Saved: {MODEL_PATH}/gru_training_curves.png')

# ── Evaluate ──────────────────────────────────────────────────
best_model = keras.models.load_model(MODEL_SAVE_PATH)
y_prob     = best_model.predict(X_test, batch_size=BATCH_SIZE, verbose=0)
y_pred     = np.argmax(y_prob, axis=1)

test_acc  = accuracy_score(y_test, y_pred)
macro_f1  = f1_score(y_test, y_pred, average='macro',    zero_division=0)
weight_f1 = f1_score(y_test, y_pred, average='weighted', zero_division=0)

print()
print('='*55)
print('GRU — TEST SET RESULTS')
print('='*55)
print(f'  Overall Accuracy : {test_acc:.4f}  ({test_acc*100:.1f}%)')
print(f'  Macro F1 Score   : {macro_f1:.4f}  ({macro_f1*100:.1f}%)')
print(f'  Weighted F1 Score: {weight_f1:.4f}  ({weight_f1*100:.1f}%)')
print()
print(f'  Target accuracy >85% : {"✅ PASS" if test_acc>=0.85 else "❌ BELOW"}  ({test_acc*100:.1f}%)')
print(f'  Target macro F1 >80% : {"✅ PASS" if macro_f1>=0.80 else "❌ BELOW"}  ({macro_f1*100:.1f}%)')
print()
print(classification_report(y_test, y_pred,
      target_names=LABEL_NAMES, zero_division=0))

# ── Confusion Matrix ──────────────────────────────────────────
cm      = confusion_matrix(y_test, y_pred)
cm_norm = cm.astype(float) / cm.sum(axis=1, keepdims=True)

fig, axes = plt.subplots(1, 2, figsize=(16,6))
sns.heatmap(cm, annot=True, fmt='d',
            xticklabels=LABEL_NAMES, yticklabels=LABEL_NAMES,
            cmap='Blues', ax=axes[0])
axes[0].set_title('Confusion Matrix — Raw Counts',
                  fontsize=13, fontweight='bold')
axes[0].set_xlabel('Predicted'); axes[0].set_ylabel('True')
axes[0].tick_params(axis='x', rotation=30)

sns.heatmap(cm_norm, annot=True, fmt='.2f',
            xticklabels=LABEL_NAMES, yticklabels=LABEL_NAMES,
            cmap='Blues', vmin=0, vmax=1, ax=axes[1])
axes[1].set_title('Confusion Matrix — Normalised (Recall)',
                  fontsize=13, fontweight='bold')
axes[1].set_xlabel('Predicted'); axes[1].set_ylabel('True')
axes[1].tick_params(axis='x', rotation=30)

plt.suptitle('GRU Mental State Classifier — Confusion Matrix',
             fontsize=14, fontweight='bold')
plt.tight_layout()
plt.savefig(f'{MODEL_PATH}/gru_confusion_matrix.png', dpi=150)
plt.show()
print(f'Saved: {MODEL_PATH}/gru_confusion_matrix.png')

# ── Per-class F1 ──────────────────────────────────────────────
per_class_f1 = f1_score(y_test, y_pred, average=None, zero_division=0)
colors = ['#22C55E' if f>=0.80 else '#F59E0B' if f>=0.60 else '#EF4444'
          for f in per_class_f1]

plt.figure(figsize=(10,5))
bars = plt.bar(LABEL_NAMES, per_class_f1, color=colors,
               edgecolor='white', linewidth=0.5)
plt.axhline(y=0.80, color='green', linestyle='--', alpha=0.7, label='Target F1=0.80')
plt.axhline(y=0.60, color='orange', linestyle='--', alpha=0.5, label='Acceptable F1=0.60')
for bar, f1 in zip(bars, per_class_f1):
    plt.text(bar.get_x()+bar.get_width()/2, bar.get_height()+0.01,
             f'{f1:.3f}', ha='center', va='bottom',
             fontsize=11, fontweight='bold')
plt.title('GRU — F1 Score per Mental State',
          fontsize=14, fontweight='bold')
plt.xlabel('Mental State'); plt.ylabel('F1 Score')
plt.ylim([0,1.1]); plt.legend()
plt.grid(axis='y', alpha=0.3); plt.tight_layout()
plt.savefig(f'{MODEL_PATH}/gru_per_class_f1.png', dpi=150)
plt.show()

print('\nPer-class F1:')
for name, f1 in zip(LABEL_NAMES, per_class_f1):
    status = '✅' if f1>=0.80 else '⚠️' if f1>=0.60 else '❌'
    print(f'  {status} {name:<15}  F1={f1:.4f}')

# ── Save ──────────────────────────────────────────────────────
np.save(f'{MODEL_PATH}/gru_probs.npy', y_prob)

summary = {
    'architecture': {
        'input_shape': [SEQ_LEN, N_FEATURES],
        'gru_1_units': 128, 'dropout_1': 0.3,
        'gru_2_units': 64,  'dropout_2': 0.3,
        'output_units': N_CLASSES,
        'total_params': int(best_model.count_params())
    },
    'training': {
        'epochs_run':    len(history.history['loss']),
        'batch_size':    BATCH_SIZE,
        'best_val_loss': float(min(history.history['val_loss'])),
        'best_val_acc':  float(max(history.history['val_accuracy']))
    },
    'test_results': {
        'accuracy':    float(test_acc),
        'macro_f1':    float(macro_f1),
        'weighted_f1': float(weight_f1),
        'per_class_f1': {n: float(f) for n,f in zip(LABEL_NAMES,per_class_f1)}
    },
    'targets_met': {
        'accuracy_85pct': bool(test_acc>=0.85),
        'macro_f1_80pct': bool(macro_f1>=0.80)
    },
    'label_names': LABEL_NAMES
}
with open(f'{MODEL_PATH}/gru_training_summary.json','w') as f:
    json.dump(summary, f, indent=2)

print('\n'+'='*55)
print('GRU COMPLETE — FINAL SUMMARY')
print('='*55)
print(f'  Epochs run    : {summary["training"]["epochs_run"]}')
print(f'  Best val acc  : {summary["training"]["best_val_acc"]*100:.1f}%')
print(f'  Test accuracy : {test_acc*100:.1f}%  (target >85%)')
print(f'  Test macro F1 : {macro_f1*100:.1f}%  (target >80%)')
print()
for fname in ['gru_mental_state_best.h5','gru_training_curves.png',
              'gru_confusion_matrix.png','gru_per_class_f1.png',
              'gru_training_summary.json','gru_training_log.csv',
              'gru_probs.npy']:
    fp = f'{MODEL_PATH}/{fname}'
    exists = os.path.exists(fp)
    size   = f'{os.path.getsize(fp)/1024:.0f} KB' if exists else ''
    print(f'  {"✅" if exists else "❌"} {fname:<42} {size}')
# Out:
# Mounted at /content/drive
# Ready.
# TensorFlow : 2.20.0
# GPU        : False
# Data loaded:
#   X_train : (2721, 30, 36)  y_train : (2721,)
#   X_val   : (583, 30, 36)   y_val   : (583,)
#   X_test  : (584, 30, 36)  y_test  : (584,)
# No NaN values. Data is clean.
#
# Class distribution (train):
#   0 Waiting         1,200  ( 44.1%)  ██████████████████████
#   1 Hesitant          151  (  5.5%)  ██
#   2 Committed         549  ( 20.2%)  ██████████
#   3 Distracted        153  (  5.6%)  ██
#   4 Aggressive        431  ( 15.8%)  ███████
#   5 Jaywalk           237  (  8.7%)  ████
#
# Class weights:
#   0 Waiting          weight=0.378
#   1 Hesitant         weight=3.003
#   2 Committed        weight=0.826
#   3 Distracted       weight=2.964
#   4 Aggressive       weight=1.052
#   5 Jaywalk          weight=1.914
# Model: "GRU_MentalState"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequence_input (InputLayer)     │ (None, 30, 36)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_1 (GRU)                     │ (None, 30, 128)        │        63,744 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 30, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_2 (GRU)                     │ (None, 64)             │        37,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mental_state_output (Dense)     │ (None, 6)              │           390 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 101,382 (396.02 KB)
#  Trainable params: 101,382 (396.02 KB)
#  Non-trainable params: 0 (0.00 B)
# Total parameters : 101,382
#
# Starting GRU training...
# Epoch 1/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.4459 - loss: 1.4741
# Epoch 1: val_loss improved from None to 0.98053, saving model to /content/drive/MyDrive/PIE/models/gru_mental_state_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 1: finished saving model to /content/drive/MyDrive/PIE/models/gru_mental_state_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 13s 97ms/step - accuracy: 0.5230 - loss: 1.3044 - val_accuracy: 0.5935 - val_loss: 0.9805 - learning_rate: 0.0010
# Epoch 2/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.5729 - loss: 1.1285
# Epoch 2: val_loss improved from 0.98053 to 0.92075, saving model to /content/drive/MyDrive/PIE/models/gru_mental_state_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 2: finished saving model to /content/drive/MyDrive/PIE/models/gru_mental_state_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - accuracy: 0.5807 - loss: 1.0814 - val_accuracy: 0.6244 - val_loss: 0.9207 - learning_rate: 0.0010
# Epoch 3/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6101 - loss: 1.0495
# Epoch 3: val_loss did not improve from 0.92075
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - accuracy: 0.6016 - loss: 1.0116 - val_accuracy: 0.6192 - val_loss: 0.9348 - learning_rate: 0.0010
# Epoch 4/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6278 - loss: 0.9701
# Epoch 4: val_loss did not improve from 0.92075
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 74ms/step - accuracy: 0.6369 - loss: 0.9262 - val_accuracy: 0.6501 - val_loss: 0.9289 - learning_rate: 0.0010
# Epoch 5/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6403 - loss: 0.9343
# Epoch 5: val_loss did not improve from 0.92075
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 10s 67ms/step - accuracy: 0.6509 - loss: 0.8751 - val_accuracy: 0.6535 - val_loss: 0.9264 - learning_rate: 0.0010
# Epoch 6/100
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6659 - loss: 0.8419
# Epoch 6: val_loss improved from 0.92075 to 0.89764, saving model to /content/drive/MyDrive/PIE/models/gru_mental_state_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 6: finished saving model to /content/drive/MyDrive/PIE/models/gru_mental_state_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.6770 - loss: 0.7855 - val_accuracy: 0.6690 - val_loss: 0.8976 - learning_rate: 0.0010
# Epoch 7/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.7047 - loss: 0.7553
# Epoch 7: val_loss improved from 0.89764 to 0.82966, saving model to /content/drive/MyDrive/PIE/models/gru_mental_state_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 7: finished saving model to /content/drive/MyDrive/PIE/models/gru_mental_state_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 10s 72ms/step - accuracy: 0.7144 - loss: 0.7149 - val_accuracy: 0.7153 - val_loss: 0.8297 - learning_rate: 0.0010
# Epoch 8/100
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7171 - loss: 0.7039
# Epoch 8: val_loss improved from 0.82966 to 0.81419, saving model to /content/drive/MyDrive/PIE/models/gru_mental_state_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 8: finished saving model to /content/drive/MyDrive/PIE/models/gru_mental_state_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.7174 - loss: 0.6788 - val_accuracy: 0.7307 - val_loss: 0.8142 - learning_rate: 0.0010
# Epoch 9/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7291 - loss: 0.6529
# Epoch 9: val_loss did not improve from 0.81419
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - accuracy: 0.7321 - loss: 0.6188 - val_accuracy: 0.7204 - val_loss: 0.8199 - learning_rate: 0.0010
# Epoch 10/100
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.7565 - loss: 0.5809
# Epoch 10: val_loss improved from 0.81419 to 0.76835, saving model to /content/drive/MyDrive/PIE/models/gru_mental_state_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 10: finished saving model to /content/drive/MyDrive/PIE/models/gru_mental_state_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 8s 95ms/step - accuracy: 0.7556 - loss: 0.5538 - val_accuracy: 0.7341 - val_loss: 0.7684 - learning_rate: 0.0010
# Epoch 11/100
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.7851 - loss: 0.5286
# Epoch 11: val_loss did not improve from 0.76835
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 60ms/step - accuracy: 0.7725 - loss: 0.5130 - val_accuracy: 0.7341 - val_loss: 0.7823 - learning_rate: 0.0010
# Epoch 12/100
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.7971 - loss: 0.4750
# Epoch 12: val_loss improved from 0.76835 to 0.74789, saving model to /content/drive/MyDrive/PIE/models/gru_mental_state_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 12: finished saving model to /content/drive/MyDrive/PIE/models/gru_mental_state_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 8s 93ms/step - accuracy: 0.8004 - loss: 0.4452 - val_accuracy: 0.7650 - val_loss: 0.7479 - learning_rate: 0.0010
# Epoch 13/100
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8256 - loss: 0.4109
# Epoch 13: val_loss did not improve from 0.74789
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - accuracy: 0.8104 - loss: 0.4170 - val_accuracy: 0.7427 - val_loss: 0.7721 - learning_rate: 0.0010
# Epoch 14/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8214 - loss: 0.4086
# Epoch 14: val_loss improved from 0.74789 to 0.74629, saving model to /content/drive/MyDrive/PIE/models/gru_mental_state_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 14: finished saving model to /content/drive/MyDrive/PIE/models/gru_mental_state_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - accuracy: 0.8181 - loss: 0.4046 - val_accuracy: 0.7599 - val_loss: 0.7463 - learning_rate: 0.0010
# Epoch 15/100
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8542 - loss: 0.3430
# Epoch 15: val_loss did not improve from 0.74629
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.8416 - loss: 0.3577 - val_accuracy: 0.7564 - val_loss: 0.7487 - learning_rate: 0.0010
# Epoch 16/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.8384 - loss: 0.4004
# Epoch 16: val_loss improved from 0.74629 to 0.73482, saving model to /content/drive/MyDrive/PIE/models/gru_mental_state_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 16: finished saving model to /content/drive/MyDrive/PIE/models/gru_mental_state_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 8s 93ms/step - accuracy: 0.8350 - loss: 0.3796 - val_accuracy: 0.7684 - val_loss: 0.7348 - learning_rate: 0.0010
# Epoch 17/100
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8647 - loss: 0.3018
# Epoch 17: val_loss did not improve from 0.73482
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.8486 - loss: 0.3237 - val_accuracy: 0.7770 - val_loss: 0.7789 - learning_rate: 0.0010
# Epoch 18/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8764 - loss: 0.2911
# Epoch 18: val_loss did not improve from 0.73482
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - accuracy: 0.8692 - loss: 0.2858 - val_accuracy: 0.7581 - val_loss: 0.7605 - learning_rate: 0.0010
# Epoch 19/100
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8888 - loss: 0.2574
# Epoch 19: val_loss did not improve from 0.73482
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 85ms/step - accuracy: 0.8795 - loss: 0.2706 - val_accuracy: 0.7427 - val_loss: 0.8342 - learning_rate: 0.0010
# Epoch 20/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8938 - loss: 0.2379
# Epoch 20: val_loss did not improve from 0.73482
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 8s 60ms/step - accuracy: 0.8890 - loss: 0.2400 - val_accuracy: 0.7719 - val_loss: 0.7530 - learning_rate: 0.0010
# Epoch 21/100
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9232 - loss: 0.1997
# Epoch 21: val_loss did not improve from 0.73482
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - accuracy: 0.9100 - loss: 0.2119 - val_accuracy: 0.7633 - val_loss: 0.8169 - learning_rate: 0.0010
# Epoch 22/100
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9307 - loss: 0.1843
# Epoch 22: val_loss did not improve from 0.73482
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 0.9199 - loss: 0.1938 - val_accuracy: 0.7616 - val_loss: 0.8889 - learning_rate: 0.0010
# Epoch 23/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9112 - loss: 0.2039
# Epoch 23: val_loss did not improve from 0.73482
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 8s 82ms/step - accuracy: 0.9048 - loss: 0.2131 - val_accuracy: 0.7719 - val_loss: 0.8434 - learning_rate: 0.0010
# Epoch 24/100
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9223 - loss: 0.1831
# Epoch 24: val_loss did not improve from 0.73482
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 8s 52ms/step - accuracy: 0.9210 - loss: 0.1760 - val_accuracy: 0.7753 - val_loss: 0.8220 - learning_rate: 5.0000e-04
# Epoch 25/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9397 - loss: 0.1503
# Epoch 25: val_loss did not improve from 0.73482
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 74ms/step - accuracy: 0.9338 - loss: 0.1650 - val_accuracy: 0.7873 - val_loss: 0.8180 - learning_rate: 5.0000e-04
# Epoch 26/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9466 - loss: 0.1332
# Epoch 26: val_loss did not improve from 0.73482
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 9s 56ms/step - accuracy: 0.9441 - loss: 0.1363 - val_accuracy: 0.7839 - val_loss: 0.8500 - learning_rate: 5.0000e-04
# Epoch 27/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9537 - loss: 0.1275
# Epoch 27: val_loss did not improve from 0.73482
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 82ms/step - accuracy: 0.9449 - loss: 0.1363 - val_accuracy: 0.7787 - val_loss: 0.8612 - learning_rate: 5.0000e-04
# Epoch 28/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9622 - loss: 0.1168
# Epoch 28: val_loss did not improve from 0.73482
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - accuracy: 0.9577 - loss: 0.1209 - val_accuracy: 0.7822 - val_loss: 0.8684 - learning_rate: 5.0000e-04
# Epoch 29/100
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9602 - loss: 0.1189
# Epoch 29: val_loss did not improve from 0.73482
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - accuracy: 0.9570 - loss: 0.1230 - val_accuracy: 0.7839 - val_loss: 0.8902 - learning_rate: 5.0000e-04
# Epoch 30/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9647 - loss: 0.1052
# Epoch 30: val_loss did not improve from 0.73482
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.9614 - loss: 0.1122 - val_accuracy: 0.7770 - val_loss: 0.9167 - learning_rate: 5.0000e-04
# Epoch 31/100
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9640 - loss: 0.1004
# Epoch 31: val_loss did not improve from 0.73482
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.9647 - loss: 0.1020 - val_accuracy: 0.7873 - val_loss: 0.9140 - learning_rate: 2.5000e-04
# Epoch 31: early stopping
# Restoring model weights from the end of the best epoch: 16.
#
# Finished at epoch 31
# Best val_loss    : 0.7348
# Best val_accuracy: 0.7873
# Saved: /content/drive/MyDrive/PIE/models/gru_training_curves.png
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# =======================================================
# GRU — TEST SET RESULTS
# =======================================================
#   Overall Accuracy : 0.7466  (74.7%)
#   Macro F1 Score   : 0.6852  (68.5%)
#   Weighted F1 Score: 0.7544  (75.4%)
#
#   Target accuracy >85% : ❌ BELOW  (74.7%)
#   Target macro F1 >80% : ❌ BELOW  (68.5%)
#
#               precision    recall  f1-score   support
#
#      Waiting       0.88      0.69      0.78       257
#     Hesitant       0.38      0.61      0.47        33
#    Committed       0.82      0.90      0.86       118
#   Distracted       0.54      0.78      0.64        32
#   Aggressive       0.81      0.82      0.81        93
#      Jaywalk       0.52      0.61      0.56        51
#
#     accuracy                           0.75       584
#    macro avg       0.66      0.73      0.69       584
# weighted avg       0.78      0.75      0.75       584
# Saved: /content/drive/MyDrive/PIE/models/gru_confusion_matrix.png
# Per-class F1:
#   ⚠️ Waiting          F1=0.7756
#   ❌ Hesitant         F1=0.4651
#   ✅ Committed        F1=0.8583
#   ⚠️ Distracted       F1=0.6410
#   ✅ Aggressive       F1=0.8128
#   ❌ Jaywalk          F1=0.5586
#
# =======================================================
# GRU COMPLETE — FINAL SUMMARY
# =======================================================
#   Epochs run    : 31
#   Best val acc  : 78.7%
#   Test accuracy : 74.7%  (target >85%)
#   Test macro F1 : 68.5%  (target >80%)
#
#   ✅ gru_mental_state_best.h5                   1223 KB
#   ✅ gru_training_curves.png                    109 KB
#   ✅ gru_confusion_matrix.png                   145 KB
#   ✅ gru_per_class_f1.png                       59 KB
#   ✅ gru_training_summary.json                  1 KB
#   ✅ gru_training_log.csv                       3 KB
#   ✅ gru_probs.npy                              14 KB
